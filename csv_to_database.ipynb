# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://root:HS%402223@localhost:3306/task_management")
df = pd.read_csv("synthetic_task_dataset.csv")
df.to_sql('tasks', engine, if_exists='append', index=False)
# Out:
# 1500
